# %%
# %run Scaffold_Y_lipo.ipynb

# %%
from collections.abc import Mapping
from cameo import models
from cameo.strain_design.deterministic.flux_variability_based import FSEOF
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fseof = FSEOF(model)
result = fseof.run(target=model.reactions.DM_Eicosapentaenoic_Acid)
df = result.data_frame
df
# Out:
#                                 1         2         3         4         5   \
# ACOAH                     0.255193  0.459816  0.584248  0.708681  0.833114
# ACONT                     0.000000  0.008132  0.007258  0.006383  0.005509
# ACRNtm                    0.036568  0.105286  0.093964  0.082642  0.071320
# ASAD                     -0.004521 -0.004090 -0.003651 -0.003211 -0.002771
# ASPK                      0.004521  0.004090  0.003651  0.003211  0.002771
# ...                            ...       ...       ...       ...       ...
# D9E                       0.014310  0.028620  0.042931  0.057241  0.071551
# D8ds                      0.014310  0.028620  0.042931  0.057241  0.071551
# D5ds                      0.014310  0.028620  0.042931  0.057241  0.071551
# D17ds                     0.014310  0.028620  0.042931  0.057241  0.071551
# DM_Eicosapentaenoic_Acid  0.014310  0.028620  0.042931  0.057241  0.071551
#
#                                 6         7         8         9         10
# ACOAH                     0.957546  1.081979  1.206244  1.330152  1.454059
# ACONT                     0.004634  0.003760  0.002877  0.001978  0.001079
# ACRNtm                    0.059999  0.048677  0.037253  0.025613  0.013973
# ASAD                     -0.002331 -0.001891 -0.001447 -0.000995 -0.000543
# ASPK                      0.002331  0.001891  0.001447  0.000995  0.000543
# ...                            ...       ...       ...       ...       ...
# D9E                       0.085861  0.100171  0.114481  0.128792  0.143102
# D8ds                      0.085861  0.100171  0.114481  0.128792  0.143102
# D5ds                      0.085861  0.100171  0.114481  0.128792  0.143102
# D17ds                     0.085861  0.100171  0.114481  0.128792  0.143102
# DM_Eicosapentaenoic_Acid  0.085861  0.100171  0.114481  0.128792  0.143102
#
# [67 rows x 10 columns]

# %% [markdown]
# A change of flux is seen in 67 of the reactions, including the reactions that are inserted heterologously. The reactions giving equal numbers (such as the inserted pathway) is due to the reactions running only one way.

# %%
from matplotlib import pyplot as plt
result.data_frame.T.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.9))
plt.xlabel("Enforced flux levels")
plt.ylabel("Flux, mmol/gDW·h")
plt.show()

# %% [markdown]
# This plot doensn't prove any valuable information, but it can be visualized in a better way:

# %%
df = df.sort_values(by=df.columns[0], ascending=True)

def bar_color(df, color1, color2):
    return np.where(df.values >= 0, color1, color2)

fig, ax = plt.subplots(figsize=(20, 4))
bars = ax.bar(df.index, df[df.columns[0]], color=bar_color(df[df.columns[0]], 'green', 'red'))

ax.set_ylabel('Flux, mmol/gDW·h')
ax.set_xlabel('Reaction names')
ax.set_title('Flux scanning based on Enforced Objective Flux', size=30)

ax.set_xticklabels(df.index, rotation=90, ha='center')
ax.margins(x=0.005)


plt.show()
# Out:
# /var/folders/qk/ny241f310n36nr7k3dhymgw40000gn/T/ipykernel_16233/1627135296.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.index, rotation=90, ha='center')

# %% [markdown]
# This plot visualizes the fluxes that provide a negative (red) effect on the production of EPA, and a positive (green) effect. This also means that the ones scoring around 0 has close to no effect on the final flux of EPA, and can therefore be neglected. We can then sort the top 5 negatives against the top 5 positives.

# %%
from pytest import approx

removed_zero = (df != approx(0.0)).all(axis=1)
df = df.loc[removed_zero]
df
# Out:
#                   1         2         3         4         5         6   \
# CO2t       -2.510131 -2.529200 -2.554671 -2.580143 -2.605615 -2.631086
# PGK        -1.475488 -1.495011 -1.498434 -1.501857 -1.505279 -1.508702
# PGM        -0.707737 -0.797036 -0.885206 -0.973376 -1.061546 -1.149716
# TYRTAim    -0.079661 -0.063938 -0.057062 -0.050187 -0.043311 -0.036436
# 34HPPt2m   -0.079661 -0.063938 -0.057062 -0.050187 -0.043311 -0.036436
# ...              ...       ...       ...       ...       ...       ...
# FBA         0.749900  0.743275  0.720001  0.696727  0.673453  0.650179
# FDH         1.395423  1.269221  1.113354  0.957486  0.801619  0.645752
# MTHFD_1     1.418617  1.290206  1.132082  0.973958  0.815834  0.657710
# GAPD        1.475488  1.495011  1.498434  1.501857  1.505279  1.508702
# NADH2_u6cm  3.693620  3.511930  3.269391  3.026852  2.784313  2.541774
#
#                   7         8         9         10
# CO2t       -2.656558 -2.684830 -2.719064 -2.753298
# PGK        -1.512124 -1.516272 -1.521963 -1.527654
# PGM        -1.237886 -1.325563 -1.412188 -1.498814
# TYRTAim    -0.029560 -0.022623 -0.015554 -0.008486
# 34HPPt2m   -0.029560 -0.022623 -0.015554 -0.008486
# ...              ...       ...       ...       ...
# FBA         0.626904  0.604115  0.582359  0.560603
# FDH         0.489885  0.336577  0.188719  0.040861
# MTHFD_1     0.499586  0.344002  0.193824  0.043646
# GAPD        1.512124  1.516272  1.521963  1.527654
# NADH2_u6cm  2.299235  2.061151  1.832553  1.603955
#
# [67 rows x 10 columns]
