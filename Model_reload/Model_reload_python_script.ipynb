# %% [markdown]
# Loading the model

# %%
from cobra.io import read_sbml_model
from cobra.io import write_sbml_model
from cobra import Reaction,Metabolite

model = read_sbml_model("Loira2012_MODEL1111190000.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Adding exchange reaction EX_s_2808_b with default bounds for boundary metabolite: s_2808_b.
# Adding exchange reaction EX_s_2809_b with default bounds for boundary metabolite: s_2809_b.
# Adding exchange reaction EX_s_2810_b with default bounds for boundary metabolite: s_2810_b.
# Adding exchange reaction EX_s_3684845964903365208337918261102171132349244427641607498053451776_b with default bounds for boundary metabolite: s_3684845964903365208337918261102171132349244427641607498053451776_b.
# Adding exchange reaction EX_s_2811_b with default bounds for boundary metabolite: s_2811_b.
# Adding exchange reaction EX_s_2812_b with default bounds for boundary metabolite: s_2812_b.
# Adding exchange reaction EX_s_2813_b with default bounds for boundary metabolite: s_2813_b.
# Adding exchange reaction EX_s_2814_b with default bounds for boundary metabolite: s_2814_b.
# Adding exchange reaction EX_s_2815_b with default bounds for boundary metabolite: s_2815_b.
# Adding exchange reaction EX_s_2816_b with default bounds for boundary metabolite: s_2816_b.
# Adding exchange reaction EX_s_2817_b with default bounds for boundary metabolite: s_2817_b.
# Adding exchange reaction EX_s_2818_b with default bounds for boundary metabolite: s_2818_b.
# Adding exchange reaction EX_s_2819_b with default bounds for boundary metabolite: s_2819_b.
# Adding exchange reaction EX_s_2820_b with default bounds for boundary metabolite: s_2820_b.
# Adding exchange reaction EX_s_2821_b with default bounds for boundary metabolite: s_2821_b.
# Adding exchange reaction EX_s_2822_b with default bounds for boundary metabolite: s_2822_b.
# Adding exchange reaction EX_s_2823_b with default bounds for boundary metabolite: s_2823_b.
# Adding exchange reaction EX_s_2824_b with default bounds for boundary metabolite: s_2824_b.
# Adding exchange reaction EX_s_2825_b with default bounds for boundary metabolite: s_2825_b.
# Adding exchange reaction EX_s_2826_b with default bounds for boundary metabolite: s_2826_b.
# Adding exchange reaction EX_s_2827_b with default bounds for boundary metabolite: s_2827_b.
# Adding exchange reaction EX_s_2828_b with default bounds for boundary metabolite: s_2828_b.
# Adding exchange reaction EX_s_2829_b with default bounds for boundary metabolite: s_2829_b.
# Adding exchange reaction EX_s_2830_b with default bounds for boundary metabolite: s_2830_b.
# Adding exchange reaction EX_s_2831_b with default bounds for boundary metabolite: s_2831_b.
# Adding exchange reaction EX_s_2832_b with default bounds for boundary metabolite: s_2832_b.
# Adding exchange reaction EX_s_2963208056077732007481335863537126225285651938693716820786937856_b with default bounds for boundary metabolite: s_2963208056077732007481335863537126225285651938693716820786937856_b.
# Adding exchange reaction EX_s_2833_b with default bounds for boundary metabolite: s_2833_b.
# Adding exchange reaction EX_s_2834_b with default bounds for boundary metabolite: s_2834_b.
# Adding exchange reaction EX_s_2835_b with default bounds for boundary metabolite: s_2835_b.
# Adding exchange reaction EX_s_2836_b with default bounds for boundary metabolite: s_2836_b.
# Adding exchange reaction EX_s_2837_b with default bounds for boundary metabolite: s_2837_b.
# Adding exchange reaction EX_s_2838_b with default bounds for boundary metabolite: s_2838_b.
# Adding exchange reaction EX_s_2839_b with default bounds for boundary metabolite: s_2839_b.
# Adding exchange reaction EX_s_2840_b with default bounds for boundary metabolite: s_2840_b.
# Adding exchange reaction EX_s_2841_b with default bounds for boundary metabolite: s_2841_b.
# Adding exchange reaction EX_s_2842_b with default bounds for boundary metabolite: s_2842_b.
# Adding exchange reaction EX_s_2843_b with default bounds for boundary metabolite: s_2843_b.
# Adding exchange reaction EX_s_2844_b with default bounds for boundary metabolite: s_2844_b.
# Adding exchange reaction EX_s_2845_b with default bounds for boundary metabolite: s_2845_b.
# Adding exchange reaction EX_s_2846_b with default bounds for boundary metabolite: s_2846_b.
# Adding exchange reaction EX_s_0464_b with default bounds for boundary metabolite: s_0464_b.
# Adding exchange reaction EX_s_2847_b with default bounds for boundary metabolite: s_2847_b.
# Adding exchange reaction EX_s_2848_b with default bounds for boundary metabolite: s_2848_b.
# Adding exchange reaction EX_s_2849_b with default bounds for boundary metabolite: s_2849_b.
# Adding exchange reaction EX_s_2850_b with default bounds for boundary metabolite: s_2850_b.
# Adding exchange reaction EX_s_2851_b with default bounds for boundary metabolite: s_2851_b.
# Adding exchange reaction EX_s_2852_b with default bounds for boundary metabolite: s_2852_b.
# Adding exchange reaction EX_s_2853_b with default bounds for boundary metabolite: s_2853_b.
# Adding exchange reaction EX_s_2854_b with default bounds for boundary metabolite: s_2854_b.
# Adding exchange reaction EX_s_2855_b with default bounds for boundary metabolite: s_2855_b.
# Adding exchange reaction EX_s_2856_b with default bounds for boundary metabolite: s_2856_b.
# Adding exchange reaction EX_s_2857_b with default bounds for boundary metabolite: s_2857_b.
# Adding exchange reaction EX_s_2858_b with default bounds for boundary metabolite: s_2858_b.
# Adding exchange reaction EX_s_2859_b with default bounds for boundary metabolite: s_2859_b.
# Adding exchange reaction EX_s_2860_b with default bounds for boundary metabolite: s_2860_b.
# Adding exchange reaction EX_s_2861_b with default bounds for boundary metabolite: s_2861_b.
# Adding exchange reaction EX_s_2862_b with default bounds for boundary metabolite: s_2862_b.
# Adding exchange reaction EX_s_2863_b with default bounds for boundary metabolite: s_2863_b.
# Adding exchange reaction EX_s_2864_b with default bounds for boundary metabolite: s_2864_b.
# Adding exchange reaction EX_s_2865_b with default bounds for boundary metabolite: s_2865_b.
# Adding exchange reaction EX_s_2866_b with default bounds for boundary metabolite: s_2866_b.
# Adding exchange reaction EX_s_2867_b with default bounds for boundary metabolite: s_2867_b.
# Adding exchange reaction EX_s_2868_b with default bounds for boundary metabolite: s_2868_b.
# Adding exchange reaction EX_s_2869_b with default bounds for boundary metabolite: s_2869_b.
# Adding exchange reaction EX_s_2870_b with default bounds for boundary metabolite: s_2870_b.
# Adding exchange reaction EX_s_2871_b with default bounds for boundary metabolite: s_2871_b.
# Adding exchange reaction EX_s_2872_b with default bounds for boundary metabolite: s_2872_b.
# Adding exchange reaction EX_s_2873_b with default bounds for boundary metabolite: s_2873_b.
# Adding exchange reaction EX_s_2874_b with default bounds for boundary metabolite: s_2874_b.
# Adding exchange reaction EX_s_2875_b with default bounds for boundary metabolite: s_2875_b.
# Adding exchange reaction EX_s_2876_b with default bounds for boundary metabolite: s_2876_b.
# Adding exchange reaction EX_s_2877_b with default bounds for boundary metabolite: s_2877_b.
# Adding exchange reaction EX_s_2878_b with default bounds for boundary metabolite: s_2878_b.
# Adding exchange reaction EX_s_2879_b with default bounds for boundary metabolite: s_2879_b.
# Adding exchange reaction EX_s_2880_b with default bounds for boundary metabolite: s_2880_b.
# Adding exchange reaction EX_s_2881_b with default bounds for boundary metabolite: s_2881_b.
# Adding exchange reaction EX_s_2882_b with default bounds for boundary metabolite: s_2882_b.
# Adding exchange reaction EX_s_2883_b with default bounds for boundary metabolite: s_2883_b.
# Adding exchange reaction EX_s_0763_b with default bounds for boundary metabolite: s_0763_b.
# Adding exchange reaction EX_s_0764_b with default bounds for boundary metabolite: s_0764_b.
# Adding exchange reaction EX_s_0765_b with default bounds for boundary metabolite: s_0765_b.
# Adding exchange reaction EX_s_0766_b with default bounds for boundary metabolite: s_0766_b.
# Adding exchange reaction EX_s_0767_b with default bounds for boundary metabolite: s_0767_b.
# Adding exchange reaction EX_s_0768_b with default bounds for boundary metabolite: s_0768_b.
# Adding exchange reaction EX_s_0769_b with default bounds for boundary metabolite: s_0769_b.
# Adding exchange reaction EX_s_0770_b with default bounds for boundary metabolite: s_0770_b.
# Adding exchange reaction EX_s_0771_b with default bounds for boundary metabolite: s_0771_b.
# Adding exchange reaction EX_s_0772_b with default bounds for boundary metabolite: s_0772_b.
# Adding exchange reaction EX_s_2884_b with default bounds for boundary metabolite: s_2884_b.
# Adding exchange reaction EX_s_2885_b with default bounds for boundary metabolite: s_2885_b.
# Adding exchange reaction EX_s_0806_b with default bounds for boundary metabolite: s_0806_b.
# Adding exchange reaction EX_s_0807_b with default bounds for boundary metabolite: s_0807_b.
# Adding exchange reaction EX_s_2886_b with default bounds for boundary metabolite: s_2886_b.
# Adding exchange reaction EX_s_2887_b with default bounds for boundary metabolite: s_2887_b.
# Adding exchange reaction EX_s_2888_b with default bounds for boundary metabolite: s_2888_b.
# Adding exchange reaction EX_s_2889_b with default bounds for boundary metabolite: s_2889_b.
# Adding exchange reaction EX_s_2890_b with default bounds for boundary metabolite: s_2890_b.
# Adding exchange reaction EX_s_2891_b with default bounds for boundary metabolite: s_2891_b.
# Adding exchange reaction EX_s_2892_b with default bounds for boundary metabolite: s_2892_b.
# Adding exchange reaction EX_s_2893_b with default bounds for boundary metabolite: s_2893_b.
# Adding exchange reaction EX_s_2894_b with default bounds for boundary metabolite: s_2894_b.
# Adding exchange reaction EX_s_2895_b with default bounds for boundary metabolite: s_2895_b.
# Adding exchange reaction EX_s_2896_b with default bounds for boundary metabolite: s_2896_b.
# Adding exchange reaction EX_s_2897_b with default bounds for boundary metabolite: s_2897_b.
# Adding exchange reaction EX_s_2898_b with default bounds for boundary metabolite: s_2898_b.
# Adding exchange reaction EX_s_2899_b with default bounds for boundary metabolite: s_2899_b.
# Adding exchange reaction EX_s_2900_b with default bounds for boundary metabolite: s_2900_b.
# Adding exchange reaction EX_s_2901_b with default bounds for boundary metabolite: s_2901_b.
# Adding exchange reaction EX_s_2902_b with default bounds for boundary metabolite: s_2902_b.
# Adding exchange reaction EX_s_2903_b with default bounds for boundary metabolite: s_2903_b.
# Adding exchange reaction EX_s_2904_b with default bounds for boundary metabolite: s_2904_b.
# Adding exchange reaction EX_s_2905_b with default bounds for boundary metabolite: s_2905_b.
# Adding exchange reaction EX_s_2906_b with default bounds for boundary metabolite: s_2906_b.
# Adding exchange reaction EX_s_2907_b with default bounds for boundary metabolite: s_2907_b.
# Adding exchange reaction EX_s_2908_b with default bounds for boundary metabolite: s_2908_b.
# Adding exchange reaction EX_s_2909_b with default bounds for boundary metabolite: s_2909_b.
# Adding exchange reaction EX_s_2910_b with default bounds for boundary metabolite: s_2910_b.
# Adding exchange reaction EX_s_2911_b with default bounds for boundary metabolite: s_2911_b.
# Adding exchange reaction EX_s_2912_b with default bounds for boundary metabolite: s_2912_b.
# Adding exchange reaction EX_s_2913_b with default bounds for boundary metabolite: s_2913_b.
# Adding exchange reaction EX_s_2914_b with default bounds for boundary metabolite: s_2914_b.
# Adding exchange reaction EX_s_2915_b with default bounds for boundary metabolite: s_2915_b.
# Adding exchange reaction EX_s_2916_b with default bounds for boundary metabolite: s_2916_b.
# Adding exchange reaction EX_s_2917_b with default bounds for boundary metabolite: s_2917_b.
# Adding exchange reaction EX_s_2918_b with default bounds for boundary metabolite: s_2918_b.
# Adding exchange reaction EX_s_2919_b with default bounds for boundary metabolite: s_2919_b.
# Adding exchange reaction EX_s_2920_b with default bounds for boundary metabolite: s_2920_b.
# Adding exchange reaction EX_s_2921_b with default bounds for boundary metabolite: s_2921_b.
# Adding exchange reaction EX_s_2922_b with default bounds for boundary metabolite: s_2922_b.
# Adding exchange reaction EX_s_2923_b with default bounds for boundary metabolite: s_2923_b.
# Adding exchange reaction EX_s_2924_b with default bounds for boundary metabolite: s_2924_b.
# Adding exchange reaction EX_s_2925_b with default bounds for boundary metabolite: s_2925_b.
# Adding exchange reaction EX_s_2926_b with default bounds for boundary metabolite: s_2926_b.
# Adding exchange reaction EX_s_2927_b with default bounds for boundary metabolite: s_2927_b.
# Adding exchange reaction EX_s_2928_b with default bounds for boundary metabolite: s_2928_b.
# Adding exchange reaction EX_s_2929_b with default bounds for boundary metabolite: s_2929_b.
# Adding exchange reaction EX_s_2930_b with default bounds for boundary metabolite: s_2930_b.
# Adding exchange reaction EX_s_2931_b with default bounds for boundary metabolite: s_2931_b.
# Adding exchange reaction EX_s_2932_b with default bounds for boundary metabolite: s_2932_b.
# Adding exchange reaction EX_s_2933_b with default bounds for boundary metabolite: s_2933_b.
# Adding exchange reaction EX_s_2934_b with default bounds for boundary metabolite: s_2934_b.
# Adding exchange reaction EX_s_2935_b with default bounds for boundary metabolite: s_2935_b.
# Adding exchange reaction EX_s_2936_b with default bounds for boundary metabolite: s_2936_b.
# Adding exchange reaction EX_s_2937_b with default bounds for boundary metabolite: s_2937_b.
# Adding exchange reaction EX_s_2938_b with default bounds for boundary metabolite: s_2938_b.
# Adding exchange reaction EX_s_2939_b with default bounds for boundary metabolite: s_2939_b.
# Adding exchange reaction EX_s_2940_b with default bounds for boundary metabolite: s_2940_b.
# Adding exchange reaction EX_s_2941_b with default bounds for boundary metabolite: s_2941_b.
# Adding exchange reaction EX_s_2942_b with default bounds for boundary metabolite: s_2942_b.
# Adding exchange reaction EX_s_2943_b with default bounds for boundary metabolite: s_2943_b.
# Adding exchange reaction EX_s_2944_b with default bounds for boundary metabolite: s_2944_b.
# Adding exchange reaction EX_s_2945_b with default bounds for boundary metabolite: s_2945_b.
# Adding exchange reaction EX_s_2946_b with default bounds for boundary metabolite: s_2946_b.
# Adding exchange reaction EX_s_2947_b with default bounds for boundary metabolite: s_2947_b.
# Adding exchange reaction EX_s_2948_b with default bounds for boundary metabolite: s_2948_b.
# Adding exchange reaction EX_s_2949_b with default bounds for boundary metabolite: s_2949_b.
# Adding exchange reaction EX_s_2950_b with default bounds for boundary metabolite: s_2950_b.
# Adding exchange reaction EX_s_2951_b with default bounds for boundary metabolite: s_2951_b.
# Adding exchange reaction EX_s_2952_b with default bounds for boundary metabolite: s_2952_b.
# Adding exchange reaction EX_s_2953_b with default bounds for boundary metabolite: s_2953_b.
# Adding exchange reaction EX_s_2954_b with default bounds for boundary metabolite: s_2954_b.
# Adding exchange reaction EX_s_2955_b with default bounds for boundary metabolite: s_2955_b.
# Adding exchange reaction EX_s_2956_b with default bounds for boundary metabolite: s_2956_b.
# Adding exchange reaction EX_s_2957_b with default bounds for boundary metabolite: s_2957_b.
# Adding exchange reaction EX_s_2958_b with default bounds for boundary metabolite: s_2958_b.
# Adding exchange reaction EX_s_2959_b with default bounds for boundary metabolite: s_2959_b.
# Adding exchange reaction EX_s_2960_b with default bounds for boundary metabolite: s_2960_b.
# Adding exchange reaction EX_s_2961_b with default bounds for boundary metabolite: s_2961_b.
# Adding exchange reaction EX_s_2962_b with default bounds for boundary metabolite: s_2962_b.
# Adding exchange reaction EX_s_2963_b with default bounds for boundary metabolite: s_2963_b.
# Adding exchange reaction EX_s_2964_b with default bounds for boundary metabolite: s_2964_b.
# Adding exchange reaction EX_s_2965_b with default bounds for boundary metabolite: s_2965_b.
# Adding exchange reaction EX_s_2966_b with default bounds for boundary metabolite: s_2966_b.
# Adding exchange reaction EX_s_2967_b with default bounds for boundary metabolite: s_2967_b.
# Adding exchange reaction EX_s_2968_b with default bounds for boundary metabolite: s_2968_b.
# Adding exchange reaction EX_s_1434_b with default bounds for boundary metabolite: s_1434_b.
# Adding exchange reaction EX_s_1435_b with default bounds for boundary metabolite: s_1435_b.
# Adding exchange reaction EX_s_1436_b with default bounds for boundary metabolite: s_1436_b.
# Adding exchange reaction EX_s_1437_b with default bounds for boundary metabolite: s_1437_b.
# Adding exchange reaction EX_s_1438_b with default bounds for boundary metabolite: s_1438_b.
# Adding exchange reaction EX_s_1439_b with default bounds for boundary metabolite: s_1439_b.
# Adding exchange reaction EX_s_1440_b with default bounds for boundary metabolite: s_1440_b.
# Adding exchange reaction EX_s_1441_b with default bounds for boundary metabolite: s_1441_b.
# Adding exchange reaction EX_s_1442_b with default bounds for boundary metabolite: s_1442_b.
# Adding exchange reaction EX_s_2969_b with default bounds for boundary metabolite: s_2969_b.
# Adding exchange reaction EX_s_2970_b with default bounds for boundary metabolite: s_2970_b.
# Adding exchange reaction EX_s_2971_b with default bounds for boundary metabolite: s_2971_b.
# Adding exchange reaction EX_s_2972_b with default bounds for boundary metabolite: s_2972_b.
# Adding exchange reaction EX_s_1461_b with default bounds for boundary metabolite: s_1461_b.
# Adding exchange reaction EX_s_1462_b with default bounds for boundary metabolite: s_1462_b.
# Adding exchange reaction EX_s_1463_b with default bounds for boundary metabolite: s_1463_b.
# Adding exchange reaction EX_s_1464_b with default bounds for boundary metabolite: s_1464_b.
# Adding exchange reaction EX_s_1465_b with default bounds for boundary metabolite: s_1465_b.
# Adding exchange reaction EX_s_1466_b with default bounds for boundary metabolite: s_1466_b.
# Adding exchange reaction EX_s_1467_b with default bounds for boundary metabolite: s_1467_b.
# Adding exchange reaction EX_s_1468_b with default bounds for boundary metabolite: s_1468_b.
# Adding exchange reaction EX_s_1469_b with default bounds for boundary metabolite: s_1469_b.
# Adding exchange reaction EX_s_1470_b with default bounds for boundary metabolite: s_1470_b.
# Adding exchange reaction EX_s_1471_b with default bounds for boundary metabolite: s_1471_b.
# Adding exchange reaction EX_s_1472_b with default bounds for boundary metabolite: s_1472_b.
# Adding exchange reaction EX_s_1473_b with default bounds for boundary metabolite: s_1473_b.
# Adding exchange reaction EX_s_1474_b with default bounds for boundary metabolite: s_1474_b.
# Adding exchange reaction EX_s_1475_b with default bounds for boundary metabolite: s_1475_b.
# Adding exchange reaction EX_s_1476_b with default bounds for boundary metabolite: s_1476_b.
# Adding exchange reaction EX_s_1477_b with default bounds for boundary metabolite: s_1477_b.
# Adding exchange reaction EX_s_1478_b with default bounds for boundary metabolite: s_1478_b.
# Adding exchange reaction EX_s_1479_b with default bounds for boundary metabolite: s_1479_b.
# Adding exchange reaction EX_s_1480_b with default bounds for boundary metabolite: s_1480_b.
# Adding exchange reaction EX_s_1481_b with default bounds for boundary metabolite: s_1481_b.
# Adding exchange reaction EX_s_1482_b with default bounds for boundary metabolite: s_1482_b.
# Adding exchange reaction EX_s_1483_b with default bounds for boundary metabolite: s_1483_b.
# Adding exchange reaction EX_s_1484_b with default bounds for boundary metabolite: s_1484_b.
# Adding exchange reaction EX_s_1485_b with default bounds for boundary metabolite: s_1485_b.
# Adding exchange reaction EX_s_1486_b with default bounds for boundary metabolite: s_1486_b.
# Adding exchange reaction EX_s_1487_b with default bounds for boundary metabolite: s_1487_b.
# Adding exchange reaction EX_s_1488_b with default bounds for boundary metabolite: s_1488_b.
# Adding exchange reaction EX_s_1489_b with default bounds for boundary metabolite: s_1489_b.
# Adding exchange reaction EX_s_1490_b with default bounds for boundary metabolite: s_1490_b.
# Adding exchange reaction EX_s_1491_b with default bounds for boundary metabolite: s_1491_b.
# Adding exchange reaction EX_s_1492_b with default bounds for boundary metabolite: s_1492_b.
# Adding exchange reaction EX_s_1493_b with default bounds for boundary metabolite: s_1493_b.
# Adding exchange reaction EX_s_1494_b with default bounds for boundary metabolite: s_1494_b.
# Adding exchange reaction EX_s_1495_b with default bounds for boundary metabolite: s_1495_b.
# Adding exchange reaction EX_s_1496_b with default bounds for boundary metabolite: s_1496_b.
# Adding exchange reaction EX_s_1497_b with default bounds for boundary metabolite: s_1497_b.
# Adding exchange reaction EX_s_1498_b with default bounds for boundary metabolite: s_1498_b.
# Adding exchange reaction EX_s_1499_b with default bounds for boundary metabolite: s_1499_b.
# Adding exchange reaction EX_s_1500_b with default bounds for boundary metabolite: s_1500_b.
# Adding exchange reaction EX_s_1501_b with default bounds for boundary metabolite: s_1501_b.
# Adding exchange reaction EX_s_1502_b with default bounds for boundary metabolite: s_1502_b.
# Adding exchange reaction EX_s_1503_b with default bounds for boundary metabolite: s_1503_b.
# Adding exchange reaction EX_s_1504_b with default bounds for boundary metabolite: s_1504_b.
# Adding exchange reaction EX_s_1505_b with default bounds for boundary metabolite: s_1505_b.
# Adding exchange reaction EX_s_1506_b with default bounds for boundary metabolite: s_1506_b.
# Adding exchange reaction EX_s_1507_b with default bounds for boundary metabolite: s_1507_b.
# Adding exchange reaction EX_s_1515_b with default bounds for boundary metabolite: s_1515_b.
# Adding exchange reaction EX_s_1516_b with default bounds for boundary metabolite: s_1516_b.
# Adding exchange reaction EX_s_1526_b with default bounds for boundary metabolite: s_1526_b.
# Adding exchange reaction EX_s_1530_b with default bounds for boundary metabolite: s_1530_b.
# Adding exchange reaction EX_s_1539_b with default bounds for boundary metabolite: s_1539_b.
# Adding exchange reaction EX_s_1565_b with default bounds for boundary metabolite: s_1565_b.
# Adding exchange reaction EX_s_1634_b with default bounds for boundary metabolite: s_1634_b.
# Adding exchange reaction EX_s_1651_b with default bounds for boundary metabolite: s_1651_b.
# Adding exchange reaction EX_s_1735_b with default bounds for boundary metabolite: s_1735_b.
# Adding exchange reaction EX_s_1760_b with default bounds for boundary metabolite: s_1760_b.
# Adding exchange reaction EX_s_1775_b with default bounds for boundary metabolite: s_1775_b.
# Adding exchange reaction EX_s_1791_b with default bounds for boundary metabolite: s_1791_b.
# Adding exchange reaction EX_s_1970_b with default bounds for boundary metabolite: s_1970_b.
# Adding exchange reaction EX_s_2006_b with default bounds for boundary metabolite: s_2006_b.
# Adding exchange reaction EX_s_6867754333653150398029005077593480145909423918724892471901290496_b with default bounds for boundary metabolite: s_6867754333653150398029005077593480145909423918724892471901290496_b.
# Adding exchange reaction EX_s_2309_b with default bounds for boundary metabolite: s_2309_b.
# Adding exchange reaction EX_s_2425_b with default bounds for boundary metabolite: s_2425_b.
# Adding exchange reaction EX_s_2465_b with default bounds for boundary metabolite: s_2465_b.
# Adding exchange reaction EX_s_2502_b with default bounds for boundary metabolite: s_2502_b.
# Adding exchange reaction EX_s_2575_b with default bounds for boundary metabolite: s_2575_b.
# Adding exchange reaction EX_s_2611_b with default bounds for boundary metabolite: s_2611_b.
# Adding exchange reaction EX_s_5000_b with default bounds for boundary metabolite: s_5000_b.
# Adding exchange reaction EX_s_5003_b with default bounds for boundary metabolite: s_5003_b.
# Adding exchange reaction EX_s_5007_b with default bounds for boundary metabolite: s_5007_b.
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0001 "(R)-lactate:ferricytochrome-c 2-oxidoreductase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0001 "(R)-lactate:ferricytochrome-c 2-oxidoreductase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0002 "(R)-lactate:ferricytochrome-c 2-oxidoreductase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0002 "(R)-lactate:ferricytochrome-c 2-oxidoreductase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0003 "(R,R)-butanediol dehydrogenase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0003 "(R,R)-butanediol dehydrogenase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0004 "(S)-lactate:ferricytochrome-c 2-oxidoreductase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0004 "(S)-lactate:ferricytochrome-c 2-oxidoreductase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0005 "1,3-beta-glucan synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0005 "1,3-beta-glucan synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0006 "1,4-alpha-glucan branching enzyme">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0006 "1,4-alpha-glucan branching enzyme">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0007 "1,6-beta-glucan synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0007 "1,6-beta-glucan synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0008 "1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino)imidazole-4-carboxamide isomerase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0008 "1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino)imidazole-4-carboxamide isomerase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0010 "1-phosphatidylinositol-3-phosphate 5-kinase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0010 "1-phosphatidylinositol-3-phosphate 5-kinase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0011 "1-phosphatidylinositol-3-phosphate 5-kinase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0011 "1-phosphatidylinositol-3-phosphate 5-kinase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0012 "1-pyrroline-5-carboxylate dehydrogenase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0013 "2,3-diketo-5-methylthio-1-phosphopentane degradation reaction">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0013 "2,3-diketo-5-methylthio-1-phosphopentane degradation reaction">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0014 "2,5-diamino-6-ribitylamino-4(3H)-pyrimidinone 5'-phosphate deaminase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0014 "2,5-diamino-6-ribitylamino-4(3H)-pyrimidinone 5'-phosphate deaminase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0015 "2,5-diamino-6-ribosylamino-4(3H)-pyrimidinone 5'-phosphate reductase (NADPH)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0015 "2,5-diamino-6-ribosylamino-4(3H)-pyrimidinone 5'-phosphate reductase (NADPH)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0016 "2-aceto-2-hydroxybutanoate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0016 "2-aceto-2-hydroxybutanoate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0017 "2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0017 "2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0018 "2-aminoadipate transaminase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0019 "2-dehydropantoate 2-reductase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0019 "2-dehydropantoate 2-reductase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0020 "2-dehydropantoate 2-reductase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0020 "2-dehydropantoate 2-reductase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0021 "2-deoxy-D-arabino-heptulosonate 7-phosphate synthetase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0021 "2-deoxy-D-arabino-heptulosonate 7-phosphate synthetase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0022 "2-hexaprenyl-6-methoxy-1,4-benzoquinone methyltransferase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0022 "2-hexaprenyl-6-methoxy-1,4-benzoquinone methyltransferase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0023 "2-hexaprenyl-6-methoxyphenol monooxygenase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0023 "2-hexaprenyl-6-methoxyphenol monooxygenase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0024 "2-hydroxybutyrate:NAD+ oxidoreductase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0025 "2-isopropylmalate hydratase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0025 "2-isopropylmalate hydratase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0026 "2-isopropylmalate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0026 "2-isopropylmalate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0027 "2-isopropylmalate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0027 "2-isopropylmalate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0028 "2-keto-4-methylthiobutyrate transamination">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0029 "2-methylcitrate dehydratase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0029 "2-methylcitrate dehydratase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0030 "2-methylcitrate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0030 "2-methylcitrate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0031 "2-oxo-4-methyl-3-carboxypentanoate decarboxylation">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0031 "2-oxo-4-methyl-3-carboxypentanoate decarboxylation">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0032 "2-oxo-4-methyl-3-carboxypentanoate decarboxylation">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0032 "2-oxo-4-methyl-3-carboxypentanoate decarboxylation">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0033 "2-oxobutanoate dehydrogenase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0034 "3',5'-bisphosphate nucleotidase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0034 "3',5'-bisphosphate nucleotidase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0035 "3',5'-cyclic-nucleotide phosphodiesterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0035 "3',5'-cyclic-nucleotide phosphodiesterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0036 "3',5'-cyclic-nucleotide phosphodiesterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0036 "3',5'-cyclic-nucleotide phosphodiesterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0037 "3',5'-cyclic-nucleotide phosphodiesterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0037 "3',5'-cyclic-nucleotide phosphodiesterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0038 "3',5'-cyclic-nucleotide phosphodiesterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0038 "3',5'-cyclic-nucleotide phosphodiesterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0039 "3',5'-cyclic-nucleotide phosphodiesterase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0039 "3',5'-cyclic-nucleotide phosphodiesterase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0040 "3,4-dihydroxy-2-butanone-4-phosphate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0040 "3,4-dihydroxy-2-butanone-4-phosphate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0041 "3-(4-hydroxyphenyl-)lactate formation">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0042 "3-dehydroquinate dehydratase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0042 "3-dehydroquinate dehydratase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0043 "3-dehydroquinate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0043 "3-dehydroquinate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0045 "3-deoxy-D-arabino-heptulosonate 7-phosphate synthetase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0045 "3-deoxy-D-arabino-heptulosonate 7-phosphate synthetase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0046 "3-hexaprenyl-4,5-dihydroxybenzoate hydroxylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0047 "3-hexaprenyl-4-hydroxy-5-methoxybenzoate decarboxylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0048 "3-hydroxy-L-kynurenine hydrolase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0048 "3-hydroxy-L-kynurenine hydrolase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0049 "3-hydroxyacyl-CoA dehydratase (3-hydroxydecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0049 "3-hydroxyacyl-CoA dehydratase (3-hydroxydecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0050 "3-hydroxyacyl-CoA dehydratase (3-hydroxydodecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0050 "3-hydroxyacyl-CoA dehydratase (3-hydroxydodecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0051 "3-hydroxyacyl-CoA dehydratase (3-hydroxyhexacosyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0051 "3-hydroxyacyl-CoA dehydratase (3-hydroxyhexacosyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0052 "3-hydroxyacyl-CoA dehydratase (3-hydroxyhexadecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0052 "3-hydroxyacyl-CoA dehydratase (3-hydroxyhexadecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0053 "3-hydroxyacyl-CoA dehydratase (3-hydroxyoctadecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0053 "3-hydroxyacyl-CoA dehydratase (3-hydroxyoctadecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0054 "3-hydroxyacyl-CoA dehydratase (3-hydroxytetradecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0054 "3-hydroxyacyl-CoA dehydratase (3-hydroxytetradecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0055 "3-hydroxyacyl-CoA dehydrogenase (3-oxodecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0055 "3-hydroxyacyl-CoA dehydrogenase (3-oxodecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0056 "3-hydroxyacyl-CoA dehydrogenase (3-oxodecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0056 "3-hydroxyacyl-CoA dehydrogenase (3-oxodecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0057 "3-hydroxyacyl-CoA dehydrogenase (3-oxohexacosyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0057 "3-hydroxyacyl-CoA dehydrogenase (3-oxohexacosyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0058 "3-hydroxyacyl-CoA dehydrogenase (3-oxohexadecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0058 "3-hydroxyacyl-CoA dehydrogenase (3-oxohexadecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0059 "3-hydroxyacyl-CoA dehydrogenase (3-oxooctadecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0059 "3-hydroxyacyl-CoA dehydrogenase (3-oxooctadecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0060 "3-hydroxyacyl-CoA dehydrogenase (3-oxotetradecanoyl-CoA)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0060 "3-hydroxyacyl-CoA dehydrogenase (3-oxotetradecanoyl-CoA)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0061 "3-hydroxyanthranilate 3,4-dioxygenase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0061 "3-hydroxyanthranilate 3,4-dioxygenase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0063 "3-isopropylmalate dehydratase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0063 "3-isopropylmalate dehydratase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0064 "3-isopropylmalate dehydrogenase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0064 "3-isopropylmalate dehydrogenase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0065 "3-methyl-2-oxobutanoate decarboxylase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0065 "3-methyl-2-oxobutanoate decarboxylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0066 "3-methyl-2-oxobutanoate hydroxymethyltransferase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0066 "3-methyl-2-oxobutanoate hydroxymethyltransferase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0067 "3-methyl-2-oxopentanoate decarboxylase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0067 "3-methyl-2-oxopentanoate decarboxylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0068 "3-phosphoshikimate 1-carboxyvinyltransferase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0068 "3-phosphoshikimate 1-carboxyvinyltransferase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0069 "4-acetamidobutyrate deacetylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0070 "4-amino-4-deoxychorismate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0070 "4-amino-4-deoxychorismate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0071 "4-amino-5-hydroxymethyl-2-methylpyrimidine synthetase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0072 "4-aminobenzoate synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0072 "4-aminobenzoate synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0073 "4-aminobutyrate transaminase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0073 "4-aminobutyrate transaminase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0074 "4-hydroxy-L-threonine synthase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0074 "4-hydroxy-L-threonine synthase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0075 "4-hydroxybenzoate formation">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0076 "4-hydroxybenzoyl-CoA formation">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0077 "4-hydroxycinnamate formation">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0078 "4-methyl-2-oxopentanoate decarboxylase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0078 "4-methyl-2-oxopentanoate decarboxylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0079 "4PP-IP5 depyrophosphorylation to IP6">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0079 "4PP-IP5 depyrophosphorylation to IP6">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0080 "4PP-IP5 pyrophosphorylation to 4,5-PP2-IP4">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0080 "4PP-IP5 pyrophosphorylation to 4,5-PP2-IP4">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0081 "5'-methylthioadenosine phosphorylase">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0081 "5'-methylthioadenosine phosphorylase">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0082 "5'-nucleotidase (AMP)">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction r_0083 "5'-nucleotidase (CMP)">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction r_0083 "5'-nucleotidase (CMP)">
# ...
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_96_exchange "L-glutamate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_97_exchange "L-glutamine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_98_exchange "L-histidine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_99_exchange "L-isoleucine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_100_exchange "L-leucine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_101_exchange "L-lysine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_102_exchange "L-methionine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_103_exchange "L-phenylalanine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_104_exchange "L-proline exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_105_exchange "L-serine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_106_exchange "L-sorbose exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_107_exchange "L-threonine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_108_exchange "L-tryptophan exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_109_exchange "L-tyrosine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_110_exchange "L-valine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_111_exchange "lanosterol exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_112_exchange "laurate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_113_exchange "lignoceric acid exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_114_exchange "linoleic acid exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_115_exchange "maltose exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_116_exchange "melibiose exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_117_exchange "myo-inositol exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_118_exchange "myristate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_119_exchange "myristoleate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_120_exchange "N,N'-diformyldityrosine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_121_exchange "NADP(+) exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_122_exchange "nicotinate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_123_exchange "NMN exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_124_exchange "octanoate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_125_exchange "oleate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_126_exchange "ornithine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_127_exchange "oxaloacetate(2-) exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_128_exchange "oxygen exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_129_exchange "palmitate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_130_exchange "palmitoleate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_131_exchange "pectin exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_132_exchange "phenethyl acetate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_133_exchange "phenylacetaldehyde exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_134_exchange "phosphate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_135_exchange "phospholipid exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_136_exchange "potassium exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_137_exchange "putrescine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_138_exchange "pyridoxine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_139_exchange "pyruvate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_140_exchange "riboflavin exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_141_exchange "S-adenosyl-L-methionine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_142_exchange "S-methyl-L-methionine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_143_exchange "sn-glycero-3-phosphocholine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_144_exchange "sodium exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_145_exchange "spermidine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_146_exchange "spermine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_147_exchange "stearate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_148_exchange "succinate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_149_exchange "sucrose exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_150_exchange "sulphate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_151_exchange "sulphite exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_152_exchange "taurine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_153_exchange "thiamine(1+) exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_154_exchange "thiamine(1+) diphosphate(1-) exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_155_exchange "thiamine(1+) monophosphate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_156_exchange "thymidine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_157_exchange "thymine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_158_exchange "tryptophol exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_159_exchange "uracil exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_160_exchange "urea exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_161_exchange "uridine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_162_exchange "water exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_163_exchange "xanthosine exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_164_exchange "xylitol exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_165_exchange "zymosterol exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_1_bb "V-ATPase, Golgi">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2_bb "V-ATPase, vacuole">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_25_cl "1-acyl-sn-gylcerol-3-phosphate acyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_001_xxx "1-acyl-sn-gylcerol-3-phosphate acyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_002_xxx "mevalonate kinase (UTP)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_003_xxx "AKG transporter, mitochonrial">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_004_xxx "5-formyltetrahydrofolic acid transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_005_xxx "5-formyltetrahydrofolic acid exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_006_xxx "folic acid transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_007_xxx "folic acid exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_008_xxx "(R)-mevalonate transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_009_xxx "(R)-mevalonate exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_010_xxx "glycinamide ribonucleotide transformylase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_011_xxx "5,6,7,8-tetrahydrofolate:NAD+ oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_012_xxx "dihydrofolate:NADP+ oxidoreductase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_013_xxx "dolichyl-phosphate-mannose--protein mannosyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_014_xxx "acid phosphatase (secreted)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_015_xxx "phosphoglucomutase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_016_xxx "tetrahydrofolate:L-glutamate gamma-ligase (ADP-forming)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_017_xxx "glucose transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_018_xxx "L-histidine transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_019_xxx "phosphoribosylpyrophosphate synthetase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_020_xxx "IMP dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_021_xxx "biomass production">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_022_xxx "(1->6)-beta-D-glucan transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2000_exchange "decane exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2001 "decane transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2002 "decane dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2003_exchange "hexadecane exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2004 "hexadecane transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2005 "hexadecane dehydrogenase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2006 "phosphatidylcholine_diacylglycerol_acyltransferase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2007 "1-acylglycerophosphocholine transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2008 "ATP-citrate lyase">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2009_exchange "tributyrin exchange">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2010 "extracellular tributyrin hydrolysis">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2011 "extracellular dibutyrin hydrolysis">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2012 "extracellular monobutyrate hydrolysis">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2013 "butyrate transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2014 "butyrate perox. transport">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2015 "fatty-acid--CoA ligase (butyrate)">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction r_2016 "fatty acid oxidation (butyryl-CoA)">

# %% [markdown]
# write_sbml_model()

# %%
write_sbml_model(model,"Loira2012_MODEL1111190000_2.xml")
