# %% [markdown]
# Loading the model

# %%
from cobra.io import read_sbml_model
from cobra.io import write_sbml_model
from cobra import Reaction,Metabolite

model = read_sbml_model("Kavšček2015_iMK735_MODEL1510060001.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_10fthf_c "M_10_Formyltetrahydrofolate_C20H21N7O7">
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_10fthf_m "M_10_Formyltetrahydrofolate_C20H21N7O7">
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_12dgr_SC_c "M_1_2_Diacylglycerol__yeast_specific_C3540H6644O500">
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_13BDglcn_c "M_1_3_beta_D_Glucan_C6H10O5">
# Use of the species charge attribute is discouraged, use fbc:charge instead: <Species M_13BDglcn_e "M_1_3_beta_D_Glucan_C6H10O5">
# ...

# %% [markdown]
# write_sbml_model()

# %%
write_sbml_model(model,"Kavšček2015_iMK735_MODEL1510060001_2.xml")
